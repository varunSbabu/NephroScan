# %% [markdown]
# Import dependencies

# %%
import pandas as pd
import os
import sys

# %%
sys.path.append('c:\\Users\\salah\\CKD\\src')

from model import define_and_train_models , save_models
from preprocessing import preprocess_data

# %%
DATA_PATH = '../data/raw.csv'


TARGET_COLUMN = 'classification'

# %%
# Preprocessing
X, y = preprocess_data(DATA_PATH , TARGET_COLUMN)

# %%
#train the models
trained_models = define_and_train_models(X, y)
# Out:
# Training Logistic Regression...
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training SVM...
# Training Decision Tree...
# Training Random Forest...
# Training Gradient Boosting...
# Training XGBoost...
# Training CatBoost...
# Training K-Nearest Neighbors...
# Training Naive Bayes...
# All models have been trained successfully.

# %%
X
# Out:
# array([[48.   , 80.   ,  1.02 , ...,  1.   ,  0.   ,  0.   ],
#        [ 7.   , 50.   ,  1.02 , ...,  1.   ,  0.   ,  0.   ],
#        [62.   , 80.   ,  1.01 , ...,  0.   ,  0.   ,  1.   ],
#        ...,
#        [12.   , 80.   ,  1.02 , ...,  1.   ,  0.   ,  0.   ],
#        [17.   , 60.   ,  1.025, ...,  1.   ,  0.   ,  0.   ],
#        [58.   , 80.   ,  1.025, ...,  1.   ,  0.   ,  0.   ]])

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: classification, Length: 400, dtype: int64

# %%
#save the models
save_models(trained_models, models_dir="../models/")
# Out:
# Saved Logistic Regression to ../models/Logistic_Regression.pkl
# Saved SVM to ../models/SVM.pkl
# Saved Decision Tree to ../models/Decision_Tree.pkl
# Saved Random Forest to ../models/Random_Forest.pkl
# Saved Gradient Boosting to ../models/Gradient_Boosting.pkl
# Saved XGBoost to ../models/XGBoost.pkl
# Saved CatBoost to ../models/CatBoost.pkl
# Saved K-Nearest Neighbors to ../models/K-Nearest_Neighbors.pkl
# Saved Naive Bayes to ../models/Naive_Bayes.pkl
# All models have been saved successfully.

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data (replace this with your actual test data)
test_data = pd.DataFrame({
    'age': [48.0],
    'bp': [80.0],
    'sg': [1.02],
    'al': [1.0],
    'su': [0.0],
    'rbc': ['abnormal'],
    'pc': ['normal'],
    'pcc': ['notpresent'],
    'ba': ['notpresent'],
    'bgr': [121.0],
    'bu': [36.0],
    'sc': [1.2],
    'sod': [140.0],
    'pot': [5.0],
    'hemo': [15.4],
    'pcv': [44],
    'wc': [7800],
    'rc': [5.2],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['good'],
    'pe': ['no'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Model: Logistic Regression, Prediction: Not CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: Not CKD
# Model: Random Forest, Prediction: Not CKD
# Model: Gradient Boosting, Prediction: Not CKD
# Model: XGBoost, Prediction: Not CKD
# Model: CatBoost, Prediction: Not CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [65.0],
    'bp': [150.0],
    'sg': [1.010],
    'al': [3.0],
    'su': [2.0],
    'rbc': ['abnormal'],
    'pc': ['abnormal'],
    'pcc': ['present'],
    'ba': ['present'],
    'bgr': [350.0],
    'bu': [120.0],
    'sc': [3.5],
    'sod': [135.0],
    'pot': [5.5],
    'hemo': [8.0],
    'pcv': [25],
    'wc': [12000],
    'rc': [3.0],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['yes'],
    'appet': ['poor'],
    'pe': ['yes'],
    'ane': ['yes']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Model: Logistic Regression, Prediction: Not CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: CKD
# Model: Random Forest, Prediction: CKD
# Model: Gradient Boosting, Prediction: CKD
# Model: XGBoost, Prediction: CKD
# Model: CatBoost, Prediction: CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [8.0],
    'bp': [80.0],
    'sg': [1.02],
    'al': [1.0],
    'su': [0.0],
    'rbc': [None],
    'pc': ['normal'],
    'pcc': ['notpresent'],
    'ba': ['notpresent'],
    'bgr': [121.0],
    'bu': [36.0],
    'sc': [1.2],
    'sod': [None],
    'pot': [None],
    'hemo': [15.4],
    'pcv': [44],
    'wc': [7800],
    'rc': [5.2],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['good'],
    'pe': ['no'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Model: Logistic Regression, Prediction: Not CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: Not CKD
# Model: Random Forest, Prediction: Not CKD
# Model: Gradient Boosting, Prediction: Not CKD
# Model: XGBoost, Prediction: Not CKD
# Model: CatBoost, Prediction: Not CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Provided test data
data = """
id,age,bp,sg,al,su,rbc,pc,pcc,ba,bgr,bu,sc,sod,pot,hemo,pcv,wc,rc,htn,dm,cad,appet,pe,ane,classification
1,63.0,70.0,1.01,3.0,0.0,abnormal,abnormal,present,notpresent,380.0,60.0,2.7,131.0,4.2,10.8,32,4500,3.8,yes,yes,no,poor,yes,no,ckd
12,68.0,70.0,1.015,3.0,1.0,,normal,present,notpresent,208.0,72.0,2.1,138.0,5.8,9.7,28,12200,3.4,yes,yes,yes,poor,yes,no,ckd
"""

# Convert the provided data to a pandas DataFrame
test_data = pd.read_csv(pd.compat.StringIO(data))

# Drop the 'id' and 'classification' columns
test_data = test_data.drop(columns=['id', 'classification'])

# Convert categorical features to numerical
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction

# Print the results
for name, prediction in predictions.items():
    results = ['CKD' if p == 1 else 'Not CKD' for p in prediction]
    print(f"Model: {name}, Predictions: {results}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 29
#      22 data = """
#      23 id,age,bp,sg,al,su,rbc,pc,pcc,ba,bgr,bu,sc,sod,pot,hemo,pcv,wc,rc,htn,dm,cad,appet,pe,ane,classification
#      24 1,63.0,70.0,1.01,3.0,0.0,abnormal,abnormal,present,notpresent,380.0,60.0,2.7,131.0,4.2,10.8,32,4500,3.8,yes,yes,no,poor,yes,no,ckd
#      25 12,68.0,70.0,1.015,3.0,1.0,,normal,present,notpresent,208.0,72.0,2.1,138.0,5.8,9.7,28,12200,3.4,yes,yes,yes,poor,yes,no,ckd
#      26 """
#      28 # Convert the provided data to a pandas DataFrame
# ---> 29 test_data = pd.read_csv(pd.compat.StringIO(data))
#      31 # Drop the 'id' and 'classification' columns
#      32 test_data = test_data.drop(columns=['id', 'classification'])
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [63.0],
    'bp': [70.0],
    'sg': [1.01],
    'al': [3.0],
    'su': [0.0],
    'rbc': ['abnormal'],
    'pc': ['abnormal'],
    'pcc': ['present'],
    'ba': ['notpresent'],
    'bgr': [380.0],
    'bu': [60.0],
    'sc': [2.7],
    'sod': [131.0],
    'pot': [4.2],
    'hemo': [10.8],
    'pcv': [32],
    'wc': [4500],
    'rc': [3.8],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['poor'],
    'pe': ['yes'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Model: Logistic Regression, Prediction: CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: CKD
# Model: Random Forest, Prediction: CKD
# Model: Gradient Boosting, Prediction: CKD
# Model: XGBoost, Prediction: CKD
# Model: CatBoost, Prediction: CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [63.0],
    'bp': [70.0],
    'sg': [1.01],
    'al': [3.0],
    'su': [0.0],
    'rbc': ['abnormal'],
    'pc': ['abnormal'],
    'pcc': ['present'],
    'ba': ['notpresent'],
    'bgr': [380.0],
    'bu': [60.0],
    'sc': [2.7],
    'sod': [131.0],
    'pot': [4.2],
    'hemo': [10.8],
    'pcv': [32],
    'wc': [4500],
    'rc': [3.8],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['poor'],
    'pe': ['yes'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Model: Logistic Regression, Prediction: CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: CKD
# Model: Random Forest, Prediction: CKD
# Model: Gradient Boosting, Prediction: CKD
# Model: XGBoost, Prediction: CKD
# Model: CatBoost, Prediction: CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [8.0],
    'bp': [80.0],
    'sg': [1.02],
    'al': [1.0],
    'su': [0.0],
    'rbc': [None],
    'pc': ['normal'],
    'pcc': ['notpresent'],
    'ba': ['notpresent'],
    'bgr': [121.0],
    'bu': [36.0],
    'sc': [1.2],
    'sod': [None],
    'pot': [None],
    'hemo': [15.4],
    'pcv': [44],
    'wc': [7800],
    'rc': [5.2],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['good'],
    'pe': ['no'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Print input values
print("Input values:")
print(test_data)

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Input values:
#    age    bp    sg   al   su  rbc  pc  pcc  ba    bgr  ...  hemo  pcv    wc  \
# 0  8.0  80.0  1.02  1.0  0.0    0   0    0   0  121.0  ...  15.4   44  7800
#
#     rc  htn  dm  cad  appet  pe  ane
# 0  5.2    0   0    0      0   0    0
#
# [1 rows x 24 columns]
# Model: Logistic Regression, Prediction: Not CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: Not CKD
# Model: Random Forest, Prediction: Not CKD
# Model: Gradient Boosting, Prediction: Not CKD
# Model: XGBoost, Prediction: Not CKD
# Model: CatBoost, Prediction: Not CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define model paths
MODEL_PATHS = {
    "Logistic Regression": '../models/Logistic_Regression.pkl',
    "SVM": '../models/SVM.pkl',
    "Decision Tree": '../models/Decision_Tree.pkl',
    "Random Forest": '../models/Random_Forest.pkl',
    "Gradient Boosting": '../models/Gradient_Boosting.pkl',
    "XGBoost": '../models/XGBoost.pkl',
    "CatBoost": '../models/CatBoost.pkl',
    "K-Nearest Neighbors": '../models/K-Nearest_Neighbors.pkl',
    "Naive Bayes": '../models/Naive_Bayes.pkl'
}

# Load all models
loaded_models = {name: joblib.load(path) for name, path in MODEL_PATHS.items()}

# Example test data with indicators of CKD (replace with actual test data)
# Example test data with indicators of CKD (replace with actual test data)
test_data = pd.DataFrame({
    'age': [63.0],
    'bp': [70.0],
    'sg': [1.01],
    'al': [3.0],
    'su': [0.0],
    'rbc': ['abnormal'],
    'pc': ['abnormal'],
    'pcc': ['present'],
    'ba': ['notpresent'],
    'bgr': [380.0],
    'bu': [60.0],
    'sc': [2.7],
    'sod': [131.0],
    'pot': [4.2],
    'hemo': [10.8],
    'pcv': [32],
    'wc': [4500],
    'rc': [3.8],
    'htn': ['yes'],
    'dm': ['yes'],
    'cad': ['no'],
    'appet': ['poor'],
    'pe': ['yes'],
    'ane': ['no']
})

# Convert categorical features to numerical (example)
label_encoders = {}
for column in test_data.columns:
    if test_data[column].dtype == 'object':
        label_encoders[column] = LabelEncoder()
        test_data[column] = label_encoders[column].fit_transform(test_data[column])

# Print input values
print("Input values:")
print(test_data)

# Predict with all models
predictions = {}
for name, model in loaded_models.items():
    prediction = model.predict(test_data)
    predictions[name] = prediction[0]

# Print the results
for name, prediction in predictions.items():
    print(f"Model: {name}, Prediction: {'CKD' if prediction == 1 else 'Not CKD'}")
# Out:
# Input values:
#     age    bp    sg   al   su  rbc  pc  pcc  ba    bgr  ...  hemo  pcv    wc  \
# 0  63.0  70.0  1.01  3.0  0.0    0   0    0   0  380.0  ...  10.8   32  4500
#
#     rc  htn  dm  cad  appet  pe  ane
# 0  3.8    0   0    0      0   0    0
#
# [1 rows x 24 columns]
# Model: Logistic Regression, Prediction: CKD
# Model: SVM, Prediction: CKD
# Model: Decision Tree, Prediction: CKD
# Model: Random Forest, Prediction: CKD
# Model: Gradient Boosting, Prediction: CKD
# Model: XGBoost, Prediction: CKD
# Model: CatBoost, Prediction: CKD
# Model: K-Nearest Neighbors, Prediction: CKD
# Model: Naive Bayes, Prediction: CKD
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\salah\anaconda3\envs\ckd_env\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(
